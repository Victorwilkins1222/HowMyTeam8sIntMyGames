# %%
from config import API_KEY
print(repr(API_KEY))
print(len(API_KEY))
# Out:
# 'RGAPI-ea9a77bd-7fa7-4b6e-83e5-e5453e39059d'
# 42

# %%
import os
print(os.listdir("data"))
# Out:
# ['.DS_Store', 'NA1_5575385488.json', 'NA1_5575391481.json', 'NA1_5575394135.json', 'NA1_5575158456.json', 'NA1_5575153596.json']

# %%
from API_Caller import pull_all_matches
matches = pull_all_matches(game_name="PressRtoDragon", tag_line="3780", count=5)
# Out:
# Getting PUUID for PressRtoDragon#3780...
# Fetching last 5 ranked match IDs...
# [1/5] Fetching NA1_5575394135...
# [2/5] Fetching NA1_5575391481...
# [3/5] Fetching NA1_5575385488...
# [4/5] Fetching NA1_5575158456...
# [5/5] Fetching NA1_5575153596...
# Done. Files saved in data/
