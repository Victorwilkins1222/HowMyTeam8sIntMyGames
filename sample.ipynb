# %%
import pandas as pd
from Data_Loader import load_matches_to_dataframe
from Scoring import run_full_pipeline

pd.set_option('display.max_rows', None)


df = load_matches_to_dataframe()          # step 1: load raw data
scored_df, leaderboard = run_full_pipeline(df,self_name='PressRtoDragon')  # step 2: score it

leaderboard
# Out:
#             match_id       player_name     role team_id   win  kills  deaths  \
# 15    NA1_5569076513          Ol Revan   JUNGLE     200  0.00   3.00   13.00
# 259   NA1_5569698655          Croupier   MIDDLE     200  0.00   0.00   18.00
# 39    NA1_5569740903        Clown Girl   BOTTOM     100  0.00   0.00   10.00
# 67    NA1_5570837155  step on me reyna   BOTTOM     100  0.00   4.00   12.00
# 28    NA1_5560445157         Do0dlebop      TOP     100  0.00   2.00   10.00
# 82    NA1_5568230600           Moscito      TOP     100  0.00   4.00   14.00
# 24    NA1_5568841666      LucentJehaya   JUNGLE     200  0.00   9.00   16.00
# 148   NA1_5575158456             Selic   BOTTOM     100  0.00   4.00   14.00
# 134   NA1_5560201520          CleanEye   BOTTOM     200  0.00   3.00   10.00
# 132   NA1_5560201520        0rnnlyFanz      TOP     200  0.00   2.00    8.00
# 40    NA1_5569740903    billysidestep2  UTILITY     100  0.00   0.00    9.00
# ...

# %%
from API_Caller import pull_all_matches
matches = pull_all_matches(game_name="PressRtoDragon", tag_line="3780", count=100)
# Out:
# Getting PUUID for PressRtoDragon#3780...
# Fetching last 100 ranked match IDs...
# [1/100] NA1_5575394135 already saved, skipping.
# [2/100] NA1_5575391481 already saved, skipping.
# [3/100] NA1_5575385488 already saved, skipping.
# [4/100] NA1_5575158456 already saved, skipping.
# [5/100] NA1_5575153596 already saved, skipping.
# [6/100] NA1_5575114458 already saved, skipping.
# [7/100] NA1_5575073968 already saved, skipping.
# [8/100] NA1_5571035872 already saved, skipping.
# [9/100] NA1_5571005819 already saved, skipping.
# [10/100] NA1_5570941606 already saved, skipping.
# [11/100] Fetching NA1_5570919620...
# [12/100] Fetching NA1_5570837155...
# [13/100] Fetching NA1_5570793459...
# [14/100] Fetching NA1_5570782812...
# [15/100] Fetching NA1_5570733872...
# [16/100] Fetching NA1_5570191776...
# [17/100] Fetching NA1_5570123311...
# [18/100] Fetching NA1_5569771889...
# [19/100] Fetching NA1_5569740903...
# [20/100] Fetching NA1_5569698655...
# ...
